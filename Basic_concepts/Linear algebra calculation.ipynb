# %%
from numpy.linalg import det,inv
from numpy import array,matrix

# %%
#mat_a=matrix([[-2,3,-1],[1,2,-1],[-2,-1,1]])
mat_a=array([[-2,3,-1],[1,2,-1],[-2,-1,1]])

# %%
det(mat_a)
# Out:
# -1.9999999999999998

# %%
inv(mat_a)
# Out:
# array([[-0.5,  1. ,  0.5],
#        [-0.5,  2. ,  1.5],
#        [-1.5,  4. ,  3.5]])

# %%
cof_matrix=array([[-2,3,-1],[1,2,-1],[-2,-1,1]])
#y=array([[1],[4],[-3]])
y=array([[1,4,-3]])

# %%
y.shape
# Out:
# (1, 3)

# %%
y.reshape(3,1)
# Out:
# array([[ 1],
#        [ 4],
#        [-3]])

# %%
#Transpose y
y.T
# Out:
# array([[ 1],
#        [ 4],
#        [-3]])

# %%
inv(cof_matrix)@y.T
# Out:
# array([[2.],
#        [3.],
#        [4.]])
